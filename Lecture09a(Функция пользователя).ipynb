# %% [markdown]
# ### Создание функции пользователя  в Python

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('vUB-TadP5Y0')

# %% [markdown]
# ### Программный код

# %%
# Подключаем библиотеки
import math as mt
import numpy as np
import matplotlib.pyplot as plt
# Задаём функцию
def f(x):
    d =x*x +np.sin(x)/x             
    return d
# Вычисляем  диапазон изменения х и у
x = np.linspace(1,20,10)
y=f(x)
#Строим график функции
plt.grid()
plt.plot(x,y)
