# %% [markdown]
# ## Линейный вычислительный процесс

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math as mt
x=1
y=0.75
z=0.15
a=(x**3/mt.cos(y)**(2/3)) + mt.log10(y)/mt.tan(z)
b=mt.sqrt((x-y)**(1/3)/(mt.asin(z)+3.6))
print('a=',round(a,3),'b=',round(b,4))
# Out:
# a= 0.405 b= 0.4098
